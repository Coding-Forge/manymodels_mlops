# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# # Data Preparation
# ---
#
# This repository uses simulated orange juice sales data from [Azure Open Datasets](https://azure.microsoft.com/services/open-datasets/) to walk you through the process of training many models and forecasting on Azure Machine Learning.
#
# This notebook walks you through all the necessary steps to configure the data for this solution accelerator, including:
#
# 1. Download the sample data
# 2. Split in training/forecasting sets
# 3. Connect to your workspace and upload the data to its Datastore
#
# ### Prerequisites
# If you have already run the [00_Setup_AML_Workspace](00_Setup_AML_Workspace.ipynb) notebook you are all set.

# %% [markdown]
# ## 1.0 Download sample data
#
# The time series data used in this example was simulated based on the University of Chicago's Dominick's Finer Foods dataset, which featured two years of sales of 3 different orange juice brands for individual stores. You can learn more about the dataset [here](https://azure.microsoft.com/services/open-datasets/catalog/sample-oj-sales-simulated/).
#
# The full dataset includes simulated sales for 3,991 stores with 3 orange juice brands each, thus allowing 11,973 models to be trained to showcase the power of the many models pattern. Each series contains data from '1990-06-14' to '1992-10-01'.

# %% [markdown]
# You'll need the `azureml-opendatasets` package to download the data. You can install it with the following:

# %%
# !pip install azureml-opendatasets
# Out:
# Requirement already satisfied: azureml-opendatasets in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.33.0)
# Requirement already satisfied: pyarrow>=0.16.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (3.0.0)
# Requirement already satisfied: azureml-dataset-runtime[fuse,pandas]~=1.33.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (1.33.0)
# Collecting scipy<=1.4.1,>=1.0.0
#   Downloading scipy-1.4.1-cp36-cp36m-manylinux1_x86_64.whl (26.1 MB)
#      |████████████████████████████████| 26.1 MB 30.1 MB/s eta 0:00:01████████████████████████▏  | 23.8 MB 30.1 MB/s eta 0:00:01
# Requirement already satisfied: azureml-core~=1.33.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (1.33.0)
# Requirement already satisfied: pandas<=2.0.0,>=0.21.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (0.25.3)
# Requirement already satisfied: pyspark in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (3.1.2)
# Requirement already satisfied: numpy<=1.19.0,>=1.16.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (1.18.5)
# Requirement already satisfied: azureml-telemetry~=1.33.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (1.33.0)
# Requirement already satisfied: azureml-dataprep<2.21.0a,>=2.20.0a in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (2.20.1)
# Requirement already satisfied: fusepy<4.0.0,>=3.0.1; extra == "fuse" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (3.0.1)
# Requirement already satisfied: jsonpickle<3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (2.0.0)
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (8.1.0)
# Requirement already satisfied: msrest<1.0.0,>=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.6.21)
# Requirement already satisfied: pytz in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (2021.1)
# Requirement already satisfied: jmespath<1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.10.0)
# Requirement already satisfied: ruamel.yaml<0.17.5,>=0.15.35 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.17.4)
# Requirement already satisfied: contextlib2<1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.6.0.post1)
# Requirement already satisfied: docker<5.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (4.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.19.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (2.26.0)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (1.0)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (3.4.7)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.61.1)
# Requirement already satisfied: azure-mgmt-authorization<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.61.0)
# Requirement already satisfied: msrestazure<=0.6.4,>=0.4.33 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.6.4)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.5.1)
# Requirement already satisfied: pathspec<1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.9.0)
# Requirement already satisfied: PyJWT<3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (2.1.0)
# Requirement already satisfied: pyopenssl<21.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (20.0.1)
# Requirement already satisfied: urllib3<=1.26.5,>=1.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (1.25.11)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (1.2.7)
# Requirement already satisfied: SecretStorage<4.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (3.3.1)
# Requirement already satisfied: azure-mgmt-resource<15.0.0,>=1.2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (13.0.0)
# Requirement already satisfied: azure-mgmt-keyvault<10.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (9.0.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (2.8.2)
# Requirement already satisfied: azure-mgmt-storage<16.0.0,>=1.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (11.2.0)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (1.1.27)
# Requirement already satisfied: py4j==0.10.9 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pyspark->azureml-opendatasets) (0.10.9)
# Requirement already satisfied: applicationinsights in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-telemetry~=1.33.0->azureml-opendatasets) (0.11.10)
# Requirement already satisfied: cloudpickle<2.0.0,>=1.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.6.0)
# Requirement already satisfied: azureml-dataprep-native<39.0.0,>=38.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (38.0.0)
# Requirement already satisfied: azureml-dataprep-rslex<1.19.0a,>=1.18.0dev0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.18.0)
# Requirement already satisfied: dotnetcore2<3.0.0,>=2.1.14 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (2.1.21)
# Requirement already satisfied: azure-identity<1.5.0,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.4.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonpickle<3.0.0->azureml-core~=1.33.0->azureml-opendatasets) (4.6.1)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-mgmt-containerregistry>=2.0.0->azureml-core~=1.33.0->azureml-opendatasets) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.33.0->azureml-opendatasets) (2021.5.30)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.33.0->azureml-opendatasets) (1.3.0)
# Requirement already satisfied: isodate>=0.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.33.0->azureml-opendatasets) (0.6.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ruamel.yaml<0.17.5,>=0.15.35->azureml-core~=1.33.0->azureml-opendatasets) (0.2.6)
# Requirement already satisfied: websocket-client>=0.32.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from docker<5.0.0->azureml-core~=1.33.0->azureml-opendatasets) (1.1.0)
# Requirement already satisfied: six>=1.4.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from docker<5.0.0->azureml-core~=1.33.0->azureml-opendatasets) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests<3.0.0,>=2.19.1->azureml-core~=1.33.0->azureml-opendatasets) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests<3.0.0,>=2.19.1->azureml-core~=1.33.0->azureml-opendatasets) (2.0.3)
# Requirement already satisfied: backports.weakref in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from backports.tempfile->azureml-core~=1.33.0->azureml-opendatasets) (1.0.post1)
# Requirement already satisfied: cffi>=1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0->azureml-core~=1.33.0->azureml-opendatasets) (1.14.6)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.33.0->azureml-opendatasets) (0.4.8)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from SecretStorage<4.0.0->azureml-core~=1.33.0->azureml-opendatasets) (0.7.1)
# Requirement already satisfied: distro>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from dotnetcore2<3.0.0,>=2.1.14->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.5.0)
# Requirement already satisfied: msal-extensions~=0.2.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (0.2.2)
# Requirement already satisfied: azure-core<2.0.0,>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.16.0)
# Requirement already satisfied: msal<2.0.0,>=1.3.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.13.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle<3.0.0->azureml-core~=1.33.0->azureml-opendatasets) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle<3.0.0->azureml-core~=1.33.0->azureml-opendatasets) (3.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests-oauthlib>=0.5.0->msrest<1.0.0,>=0.5.1->azureml-core~=1.33.0->azureml-opendatasets) (3.1.1)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cffi>=1.12->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0->azureml-core~=1.33.0->azureml-opendatasets) (2.20)
# Requirement already satisfied: portalocker~=1.0; platform_system != "Windows" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msal-extensions~=0.2.2->azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.7.1)
# ERROR: raiwidgets 0.7.0 has requirement jinja2==2.11.3, but you'll have jinja2 2.11.2 which is incompatible.
# ERROR: azureml-responsibleai 1.33.0 has requirement responsibleai~=0.9.1, but you'll have responsibleai 0.7.0 which is incompatible.
# ERROR: autokeras 1.0.15 has requirement tensorflow>=2.3.0, but you'll have tensorflow 2.1.0 which is incompatible.
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.5.2
#     Uninstalling scipy-1.5.2:
#       Successfully uninstalled scipy-1.5.2
# Successfully installed scipy-1.4.1

# %%
# !pip install update azureml-opendatasets
# Out:
# Collecting update
#   Downloading update-0.0.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: azureml-opendatasets in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (1.33.0)
# Collecting style==1.1.0
#   Downloading style-1.1.0-py2.py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pyspark in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (3.1.2)
# Requirement already satisfied: azureml-telemetry~=1.33.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (1.33.0)
# Requirement already satisfied: numpy<=1.19.0,>=1.16.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (1.18.5)
# Requirement already satisfied: scipy<=1.4.1,>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (1.4.1)
# Requirement already satisfied: pyarrow>=0.16.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (3.0.0)
# Requirement already satisfied: pandas<=2.0.0,>=0.21.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (0.25.3)
# Requirement already satisfied: azureml-dataset-runtime[fuse,pandas]~=1.33.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (1.33.0)
# Requirement already satisfied: azureml-core~=1.33.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-opendatasets) (1.33.0)
# Requirement already satisfied: py4j==0.10.9 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pyspark->azureml-opendatasets) (0.10.9)
# Requirement already satisfied: applicationinsights in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-telemetry~=1.33.0->azureml-opendatasets) (0.11.10)
# Requirement already satisfied: pytz>=2017.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pandas<=2.0.0,>=0.21.0->azureml-opendatasets) (2021.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from pandas<=2.0.0,>=0.21.0->azureml-opendatasets) (2.8.2)
# Requirement already satisfied: azureml-dataprep<2.21.0a,>=2.20.0a in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (2.20.1)
# Requirement already satisfied: fusepy<4.0.0,>=3.0.1; extra == "fuse" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (3.0.1)
# Requirement already satisfied: PyJWT<3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (2.1.0)
# Requirement already satisfied: azure-mgmt-authorization<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.61.0)
# Requirement already satisfied: cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (3.4.7)
# Requirement already satisfied: msrestazure<=0.6.4,>=0.4.33 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.6.4)
# Requirement already satisfied: pathspec<1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.9.0)
# Requirement already satisfied: contextlib2<1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.6.0.post1)
# Requirement already satisfied: pyopenssl<21.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (20.0.1)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.61.1)
# Requirement already satisfied: jmespath<1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.10.0)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.5.1)
# Requirement already satisfied: requests<3.0.0,>=2.19.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (2.26.0)
# Requirement already satisfied: ruamel.yaml<0.17.5,>=0.15.35 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.17.4)
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (8.1.0)
# Requirement already satisfied: azure-mgmt-keyvault<10.0.0,>=0.40.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (9.0.0)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (1.0)
# Requirement already satisfied: azure-mgmt-storage<16.0.0,>=1.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (11.2.0)
# Requirement already satisfied: jsonpickle<3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (2.0.0)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (1.2.7)
# Requirement already satisfied: urllib3<=1.26.5,>=1.23 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (1.25.11)
# Requirement already satisfied: docker<5.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (4.4.4)
# Requirement already satisfied: azure-mgmt-resource<15.0.0,>=1.2.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (13.0.0)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (1.1.27)
# Requirement already satisfied: SecretStorage<4.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (3.3.1)
# Requirement already satisfied: msrest<1.0.0,>=0.5.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-core~=1.33.0->azureml-opendatasets) (0.6.21)
# Requirement already satisfied: six>=1.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas<=2.0.0,>=0.21.0->azureml-opendatasets) (1.16.0)
# Requirement already satisfied: azureml-dataprep-native<39.0.0,>=38.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (38.0.0)
# Requirement already satisfied: azure-identity<1.5.0,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.4.1)
# Requirement already satisfied: dotnetcore2<3.0.0,>=2.1.14 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (2.1.21)
# Requirement already satisfied: azureml-dataprep-rslex<1.19.0a,>=1.18.0dev0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.18.0)
# Requirement already satisfied: cloudpickle<2.0.0,>=1.1.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.6.0)
# Requirement already satisfied: cffi>=1.12 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0->azureml-core~=1.33.0->azureml-opendatasets) (1.14.6)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.33.0->azureml-opendatasets) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests<3.0.0,>=2.19.1->azureml-core~=1.33.0->azureml-opendatasets) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests<3.0.0,>=2.19.1->azureml-core~=1.33.0->azureml-opendatasets) (2.0.3)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests<3.0.0,>=2.19.1->azureml-core~=1.33.0->azureml-opendatasets) (3.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from ruamel.yaml<0.17.5,>=0.15.35->azureml-core~=1.33.0->azureml-opendatasets) (0.2.6)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-mgmt-containerregistry>=2.0.0->azureml-core~=1.33.0->azureml-opendatasets) (1.3.0)
# Requirement already satisfied: backports.weakref in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from backports.tempfile->azureml-core~=1.33.0->azureml-opendatasets) (1.0.post1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from jsonpickle<3.0.0->azureml-core~=1.33.0->azureml-opendatasets) (4.6.1)
# Requirement already satisfied: websocket-client>=0.32.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from docker<5.0.0->azureml-core~=1.33.0->azureml-opendatasets) (1.1.0)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from SecretStorage<4.0.0->azureml-core~=1.33.0->azureml-opendatasets) (0.7.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.33.0->azureml-opendatasets) (1.3.0)
# Requirement already satisfied: isodate>=0.6.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.33.0->azureml-opendatasets) (0.6.0)
# Requirement already satisfied: msal-extensions~=0.2.2 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (0.2.2)
# Requirement already satisfied: azure-core<2.0.0,>=1.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.16.0)
# Requirement already satisfied: msal<2.0.0,>=1.3.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.13.0)
# Requirement already satisfied: distro>=1.2.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from dotnetcore2<3.0.0,>=2.1.14->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.5.0)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from cffi>=1.12->cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0->azureml-core~=1.33.0->azureml-opendatasets) (2.20)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle<3.0.0->azureml-core~=1.33.0->azureml-opendatasets) (3.10.0.0)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonpickle<3.0.0->azureml-core~=1.33.0->azureml-opendatasets) (3.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from requests-oauthlib>=0.5.0->msrest<1.0.0,>=0.5.1->azureml-core~=1.33.0->azureml-opendatasets) (3.1.1)
# Requirement already satisfied: portalocker~=1.0; platform_system != "Windows" in /anaconda/envs/azureml_py36/lib/python3.6/site-packages (from msal-extensions~=0.2.2->azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.21.0a,>=2.20.0a->azureml-dataset-runtime[fuse,pandas]~=1.33.0->azureml-opendatasets) (1.7.1)
# Installing collected packages: style, update
# Successfully installed style-1.1.0 update-0.0.1

# %% [markdown]
# We'll start by downloading the first 10 files but you can easily edit the code below to train all 11,973 models.

# %%
# !pip list
# Out:
# Package                                 Version
# --------------------------------------- -------------------
# absl-py                                 0.13.0
# adal                                    1.2.7
# aiohttp                                 3.7.4.post0
# aiohttp-cors                            0.7.0
# aioredis                                1.3.1
# ansiwrap                                0.8.4
# antlr4-python3-runtime                  4.7.2
# anyio                                   3.3.0
# applicationinsights                     0.11.10
# arch                                    4.14
# argcomplete                             1.12.3
# argon2-cffi                             20.1.0
# astor                                   0.8.1
# astroid                                 2.6.6
# astunparse                              1.6.3
# async-timeout                           3.0.1
# attrs                                   21.2.0
# autokeras                               1.0.15
# autopep8                                1.5.7
# azure-appconfiguration                  1.1.1
# azure-batch                             10.0.0
# azure-cli                               2.27.0
# azure-cli-core                          2.27.0
# azure-cli-telemetry                     1.0.6
# azure-common                            1.1.27
# azure-core                              1.16.0
# azure-cosmos                            3.2.0
# azure-datalake-store                    0.0.52
# azure-functions-devops-build            0.0.22
# azure-graphrbac                         0.61.1
# azure-identity                          1.4.1
# azure-keyvault                          1.1.0
# azure-keyvault-administration           4.0.0b3
# azure-loganalytics                      0.1.0
# azure-mgmt-advisor                      9.0.0
# azure-mgmt-apimanagement                0.2.0
# azure-mgmt-appconfiguration             2.0.0
# azure-mgmt-applicationinsights          1.0.0
# azure-mgmt-authorization                0.61.0
# azure-mgmt-batch                        15.0.0
# azure-mgmt-batchai                      7.0.0b1
# azure-mgmt-billing                      6.0.0
# azure-mgmt-botservice                   0.3.0
# azure-mgmt-cdn                          11.0.0
# azure-mgmt-cognitiveservices            12.0.0
# azure-mgmt-compute                      22.0.0
# azure-mgmt-consumption                  2.0.0
# azure-mgmt-containerinstance            1.5.0
# azure-mgmt-containerregistry            8.1.0
# azure-mgmt-containerservice             16.0.0
# azure-mgmt-core                         1.3.0
# azure-mgmt-cosmosdb                     6.4.0
# azure-mgmt-databoxedge                  1.0.0
# azure-mgmt-datalake-analytics           0.2.1
# azure-mgmt-datalake-nspkg               3.0.1
# azure-mgmt-datalake-store               0.5.0
# azure-mgmt-datamigration                9.0.0
# azure-mgmt-deploymentmanager            0.2.0
# azure-mgmt-devtestlabs                  4.0.0
# azure-mgmt-dns                          8.0.0
# azure-mgmt-eventgrid                    9.0.0
# azure-mgmt-eventhub                     4.1.0
# azure-mgmt-extendedlocation             1.0.0b2
# azure-mgmt-hdinsight                    8.0.0
# azure-mgmt-imagebuilder                 0.4.0
# azure-mgmt-iotcentral                   9.0.0b1
# azure-mgmt-iothub                       2.0.0
# azure-mgmt-iothubprovisioningservices   0.2.0
# azure-mgmt-keyvault                     9.0.0
# azure-mgmt-kusto                        0.3.0
# azure-mgmt-loganalytics                 11.0.0
# azure-mgmt-managedservices              1.0.0
# azure-mgmt-managementgroups             0.2.0
# azure-mgmt-maps                         2.0.0
# azure-mgmt-marketplaceordering          1.1.0
# azure-mgmt-media                        3.1.0
# azure-mgmt-monitor                      2.0.0
# azure-mgmt-msi                          0.2.0
# azure-mgmt-netapp                       4.0.0
# azure-mgmt-network                      19.0.0
# azure-mgmt-nspkg                        3.0.2
# azure-mgmt-policyinsights               1.0.0
# azure-mgmt-privatedns                   1.0.0
# azure-mgmt-rdbms                        9.1.0b1
# azure-mgmt-recoveryservices             2.0.0
# azure-mgmt-recoveryservicesbackup       0.14.0
# azure-mgmt-redhatopenshift              0.1.0
# azure-mgmt-redis                        13.0.0
# azure-mgmt-relay                        0.1.0
# azure-mgmt-reservations                 0.6.0
# azure-mgmt-resource                     13.0.0
# azure-mgmt-search                       8.0.0
# azure-mgmt-security                     0.6.0
# azure-mgmt-servicebus                   6.0.0
# azure-mgmt-servicefabric                0.5.0
# azure-mgmt-servicefabricmanagedclusters 1.0.0
# azure-mgmt-signalr                      1.0.0b2
# azure-mgmt-sql                          3.0.1
# azure-mgmt-sqlvirtualmachine            0.5.0
# azure-mgmt-storage                      11.2.0
# azure-mgmt-synapse                      2.0.0
# azure-mgmt-trafficmanager               0.51.0
# azure-mgmt-web                          2.0.0
# azure-multiapi-storage                  0.6.2
# azure-nspkg                             3.0.2
# azure-storage-blob                      12.8.1
# azure-storage-common                    1.4.2
# azure-storage-queue                     12.1.6
# azure-synapse-accesscontrol             0.5.0
# azure-synapse-artifacts                 0.6.0
# azure-synapse-spark                     0.2.0
# azureml-accel-models                    1.33.0
# azureml-automl-core                     1.33.0
# azureml-automl-dnn-nlp                  1.33.0
# azureml-automl-runtime                  1.33.0
# azureml-cli-common                      1.33.0
# azureml-contrib-dataset                 1.33.0
# azureml-contrib-fairness                1.33.0
# azureml-contrib-notebook                1.33.0
# azureml-contrib-pipeline-steps          1.33.0
# azureml-contrib-reinforcementlearning   1.33.0
# azureml-contrib-server                  1.33.0
# azureml-contrib-services                1.33.0
# azureml-core                            1.33.0
# azureml-datadrift                       1.33.0
# azureml-dataprep                        2.20.1
# azureml-dataprep-native                 38.0.0
# azureml-dataprep-rslex                  1.18.0
# azureml-dataset-runtime                 1.33.0
# azureml-defaults                        1.33.0
# azureml-explain-model                   1.33.0
# azureml-interpret                       1.33.0
# azureml-mlflow                          1.33.0
# azureml-opendatasets                    1.33.0
# azureml-pipeline                        1.33.0
# azureml-pipeline-core                   1.33.0
# azureml-pipeline-steps                  1.33.0
# azureml-responsibleai                   1.33.0
# azureml-samples                         0+unknown
# azureml-sdk                             1.33.0
# azureml-telemetry                       1.33.0
# azureml-tensorboard                     1.33.0
# azureml-train                           1.33.0
# azureml-train-automl                    1.33.0
# azureml-train-automl-client             1.33.0
# azureml-train-automl-runtime            1.33.0
# azureml-train-core                      1.33.0
# azureml-train-restclients-hyperdrive    1.33.0
# azureml-widgets                         1.33.0
# backcall                                0.2.0
# backports.functools-lru-cache           1.6.4
# backports.tempfile                      1.0
# backports.weakref                       1.0.post1
# bcrypt                                  3.2.0
# beautifulsoup4                          4.9.3
# bleach                                  3.3.1
# blessings                               1.7
# blis                                    0.2.4
# bokeh                                   2.3.3
# boto                                    2.49.0
# boto3                                   1.15.18
# botocore                                1.18.18
# Bottleneck                              1.3.2
# cached-property                         1.5.2
# cachetools                              4.2.2
# certifi                                 2021.5.30
# cffi                                    1.14.6
# chardet                                 4.0.0
# charset-normalizer                      2.0.3
# click                                   8.0.1
# cloudpickle                             1.6.0
# colorama                                0.4.4
# configparser                            3.7.4
# contextlib2                             0.6.0.post1
# contextvars                             2.4
# convertdate                             2.3.2
# coremltools                             2.1.0
# cryptography                            3.4.7
# cycler                                  0.10.0
# cymem                                   2.0.5
# Cython                                  0.29.24
# dask                                    2.30.0
# databricks-cli                          0.14.3
# dataclasses                             0.8
# datasets                                1.8.0
# decorator                               5.0.9
# defusedxml                              0.7.1
# Deprecated                              1.2.12
# dice-ml                                 0.6.1
# dill                                    0.3.4
# distributed                             2.30.1
# distro                                  1.5.0
# dm-tree                                 0.1.6
# docker                                  4.4.4
# dotnetcore2                             2.1.21
# dowhy                                   0.6
# econml                                  0.12.0b4
# en-core-web-sm                          2.1.0
# encrypted-inference                     0.9
# entrypoints                             0.3
# enum34                                  1.1.10
# erroranalysis                           0.1.14
# fabric                                  2.6.0
# fairlearn                               0.7.0
# fastai                                  1.0.61
# fastprogress                            1.0.0
# fbprophet                               0.5
# filelock                                3.0.12
# fire                                    0.4.0
# flake8                                  3.9.2
# Flask                                   1.0.3
# Flask-Cors                              3.0.10
# flatbuffers                             2.0
# fsspec                                  2021.7.0
# fusepy                                  3.0.1
# future                                  0.18.2
# gast                                    0.2.2
# gensim                                  3.8.3
# gevent                                  1.3.6
# gitdb                                   4.0.7
# GitPython                               3.1.18
# google-api-core                         1.31.1
# google-auth                             1.34.0
# google-auth-oauthlib                    0.4.5
# google-pasta                            0.2.0
# googleapis-common-protos                1.53.0
# gpustat                                 0.6.0
# graphviz                                0.14.2
# greenlet                                1.1.1
# grpcio                                  1.39.0
# gunicorn                                20.1.0
# gym                                     0.18.3
# h5py                                    3.1.0
# HeapDict                                1.0.1
# hiredis                                 2.0.0
# holidays                                0.9.11
# horovod                                 0.19.1
# huggingface-hub                         0.0.15
# humanfriendly                           9.2
# idna                                    3.2
# idna-ssl                                1.1.0
# imageio                                 2.9.0
# immutables                              0.15
# importlib-metadata                      4.6.1
# interpret-community                     0.19.1
# interpret-core                          0.2.5
# invoke                                  1.6.0
# ipykernel                               5.5.5
# ipython                                 7.16.1
# ipython-genutils                        0.2.0
# ipywidgets                              7.6.3
# isodate                                 0.6.0
# isort                                   5.9.3
# itsdangerous                            2.0.1
# javaproperties                          0.5.1
# jedi                                    0.17.2
# jeepney                                 0.7.1
# Jinja2                                  2.11.2
# jmespath                                0.10.0
# joblib                                  0.14.1
# jsmin                                   2.2.2
# json-logging-py                         0.2
# json5                                   0.9.6
# jsondiff                                1.2.0
# jsonpickle                              2.0.0
# jsonschema                              3.2.0
# jupyter                                 1.0.0
# jupyter-client                          6.1.12
# jupyter-console                         6.4.0
# jupyter-core                            4.7.1
# jupyter-server                          1.10.2
# jupyter-server-proxy                    3.1.0
# jupyterlab                              2.1.4
# jupyterlab-nvdashboard                  0.5.0
# jupyterlab-server                       1.2.0
# jupyterlab-widgets                      1.0.0
# jupytext                                1.6.0
# Keras                                   2.3.1
# Keras-Applications                      1.0.8
# keras-nightly                           2.5.0.dev2021032900
# Keras-Preprocessing                     1.1.2
# keras-tuner                             1.0.3
# keras2onnx                              1.6.0
# kiwisolver                              1.3.1
# knack                                   0.8.2
# kt-legacy                               1.0.3
# lazy-object-proxy                       1.6.0
# liac-arff                               2.5.0
# lightgbm                                2.3.0
# llvmlite                                0.36.0
# locket                                  0.2.1
# lunardate                               0.2.0
# lz4                                     3.1.3
# Markdown                                3.3.4
# markdown-it-py                          0.5.8
# MarkupSafe                              2.0.1
# matplotlib                              3.2.1
# mccabe                                  0.6.1
# mistune                                 0.8.4
# mkl-fft                                 1.2.0
# mkl-random                              1.1.0
# mkl-service                             2.3.0
# mlflow-skinny                           1.19.0
# mpmath                                  1.2.1
# msal                                    1.13.0
# msal-extensions                         0.2.2
# msgpack                                 1.0.2
# msrest                                  0.6.21
# msrestazure                             0.6.4
# multidict                               5.1.0
# multiprocess                            0.70.12.2
# murmurhash                              1.0.5
# nbconvert                               5.6.1
# nbformat                                5.1.3
# nbresuse                                0.4.0
# ndg-httpsclient                         0.5.1
# networkx                                2.5
# nimbusml                                1.8.0
# notebook                                6.4.0
# numba                                   0.53.1
# numexpr                                 2.7.3
# numpy                                   1.18.5
# nvidia-ml-py3                           7.352.0
# oauthlib                                3.1.1
# olefile                                 0.46
# onnx                                    1.7.0
# onnxconverter-common                    1.6.0
# onnxmltools                             1.4.1
# onnxruntime                             1.8.0
# opencensus                              0.7.13
# opencensus-context                      0.1.2
# opencensus-ext-azure                    1.0.8
# opencv-python-headless                  4.3.0.36
# opt-einsum                              3.3.0
# packaging                               21.0
# pandas                                  0.25.3
# pandas-ml                               0.6.1
# pandocfilters                           1.4.3
# papermill                               1.2.1
# paramiko                                2.7.2
# parso                                   0.8.2
# partd                                   1.2.0
# pathlib2                                2.3.6
# pathspec                                0.9.0
# patsy                                   0.5.1
# pexpect                                 4.8.0
# pickleshare                             0.7.5
# Pillow                                  8.0.0
# pip                                     20.1.1
# pkginfo                                 1.7.1
# plac                                    0.9.6
# pluggy                                  0.13.1
# pmdarima                                1.1.1
# portalocker                             1.7.1
# preshed                                 2.0.1
# prometheus-client                       0.11.0
# prompt-toolkit                          3.0.19
# property-cached                         1.6.4
# protobuf                                3.17.3
# psutil                                  5.8.0
# psycopg2                                2.8.6
# ptyprocess                              0.7.0
# py-spy                                  0.3.8
# py4j                                    0.10.9
# pyarrow                                 3.0.0
# pyasn1                                  0.4.8
# pyasn1-modules                          0.2.8
# pycocotools                             2.0.0
# pycodestyle                             2.6.0
# pycparser                               2.20
# pydantic                                1.8.2
# pydocstyle                              6.1.1
# pydot                                   1.4.2
# pyflakes                                2.2.0
# PyGithub                                1.55
# pyglet                                  1.5.15
# Pygments                                2.9.0
# PyJWT                                   2.1.0
# pylint                                  2.9.6
# PyMeeus                                 0.5.10
# PyNaCl                                  1.4.0
# pynvml                                  11.0.0
# pyodbc                                  4.0.0-unsupported
# pyOpenSSL                               20.0.1
# pyparsing                               2.4.7
# pyrsistent                              0.18.0
# pyspark                                 3.1.2
# pystan                                  2.19.0.0
# python-dateutil                         2.8.2
# python-jsonrpc-server                   0.4.0
# python-language-server                  0.35.0
# pytorch-transformers                    1.0.0
# pytz                                    2021.1
# PyWavelets                              1.1.1
# PyYAML                                  5.4.1
# pyzmq                                   22.1.0
# qtconsole                               5.1.1
# QtPy                                    1.9.0
# QuantLib                                1.23
# rai-core-flask                          0.2.2
# raiwidgets                              0.7.0
# ray                                     1.5.1
# redis                                   3.5.3
# regex                                   2021.7.6
# requests                                2.26.0
# requests-oauthlib                       1.3.0
# requests-unixsocket                     0.2.0
# responsibleai                           0.7.0
# rope                                    0.19.0
# rsa                                     4.7.2
# ruamel.yaml                             0.17.4
# ruamel.yaml.clib                        0.2.6
# s3transfer                              0.3.7
# sacremoses                              0.0.45
# scikit-image                            0.17.2
# scikit-learn                            0.22.2.post1
# scipy                                   1.4.1
# scp                                     0.13.6
# scrapbook                               0.5.0
# seaborn                                 0.11.1
# SecretStorage                           3.3.1
# semver                                  2.13.0
# Send2Trash                              1.7.1
# sentencepiece                           0.1.96
# seqeval                                 1.2.2
# setuptools                              50.3.0
# setuptools-git                          1.2
# shap                                    0.39.0
# simpervisor                             0.4
# sip                                     4.19.24
# six                                     1.16.0
# skl2onnx                                1.4.9
# sklearn                                 0.0
# sklearn-pandas                          1.7.0
# slicer                                  0.0.7
# smart-open                              1.9.0
# smmap                                   4.0.0
# sniffio                                 1.2.0
# snowballstemmer                         2.1.0
# sortedcontainers                        2.4.0
# soupsieve                               2.2.1
# spacy                                   2.1.8
# sparse                                  0.12.0
# srsly                                   1.0.5
# sshtunnel                               0.1.5
# statsmodels                             0.10.2
# style                                   1.1.0
# sympy                                   1.8
# tabulate                                0.8.9
# tblib                                   1.7.0
# tenacity                                8.0.1
# tensorboard                             2.1.1
# tensorboard-data-server                 0.6.1
# tensorboard-plugin-wit                  1.8.0
# tensorboardX                            2.4
# tensorflow                              2.1.0
# tensorflow-estimator                    2.1.0
# tensorflow-gpu                          2.1.0
# termcolor                               1.1.0
# terminado                               0.10.1
# testpath                                0.5.0
# textwrap3                               0.9.2
# thinc                                   7.0.8
# threadpoolctl                           2.1.0
# tifffile                                2020.9.3
# tokenizers                              0.10.3
# toml                                    0.10.2
# toolz                                   0.11.1
# torch                                   1.9.0
# torch-tb-profiler                       0.2.1
# torchvision                             0.9.1
# tornado                                 6.1
# tqdm                                    4.61.2
# traitlets                               4.3.3
# transformers                            4.5.1
# typed-ast                               1.4.3
# typing-extensions                       3.10.0.0
# ujson                                   4.0.2
# update                                  0.0.1
# urllib3                                 1.25.11
# uuid                                    1.30
# vsts                                    0.1.25
# wasabi                                  0.8.2
# wcwidth                                 0.2.5
# webencodings                            0.5.1
# websocket-client                        1.1.0
# websockets                              9.1
# Werkzeug                                1.0.1
# wheel                                   0.35.1
# widgetsnbextension                      3.5.1
# wrapt                                   1.12.1
# xgboost                                 0.90
# xmltodict                               0.12.0
# xxhash                                  2.0.2
# yapf                                    0.31.0
# yarl                                    1.6.3
# zict                                    2.0.0
# zipp                                    3.5.0
# zope.event                              4.5.0
# zope.interface                          5.4.0

# %%
dataset_maxfiles = 10 # Set to 11973 or 0 to get all the files

# %%
import os
from azureml.opendatasets import OjSalesSimulated

# Pull all of the data
oj_sales_files = OjSalesSimulated.get_file_dataset()

# Pull only the first `dataset_maxfiles` files
if dataset_maxfiles:
    oj_sales_files = oj_sales_files.take(dataset_maxfiles)

# Create a folder to download
target_path = 'oj_sales_data' 
os.makedirs(target_path, exist_ok=True)

# Download the data
oj_sales_files.download(target_path, overwrite=True)
# Out:
# ['/mnt/batch/tasks/shared/LS_root/mounts/clusters/coding-forge-medium/code/Users/brcampb/projects/manymodels_mlops/oj_sales_data/https%3A/%2Fazureopendatastorage.azurefd.net/ojsales-simulatedcontainer/oj_sales_data/Store1000_dominicks.csv',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/coding-forge-medium/code/Users/brcampb/projects/manymodels_mlops/oj_sales_data/https%3A/%2Fazureopendatastorage.azurefd.net/ojsales-simulatedcontainer/oj_sales_data/Store1000_minute.maid.csv',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/coding-forge-medium/code/Users/brcampb/projects/manymodels_mlops/oj_sales_data/https%3A/%2Fazureopendatastorage.azurefd.net/ojsales-simulatedcontainer/oj_sales_data/Store1000_tropicana.csv',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/coding-forge-medium/code/Users/brcampb/projects/manymodels_mlops/oj_sales_data/https%3A/%2Fazureopendatastorage.azurefd.net/ojsales-simulatedcontainer/oj_sales_data/Store1001_dominicks.csv',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/coding-forge-medium/code/Users/brcampb/projects/manymodels_mlops/oj_sales_data/https%3A/%2Fazureopendatastorage.azurefd.net/ojsales-simulatedcontainer/oj_sales_data/Store1001_minute.maid.csv',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/coding-forge-medium/code/Users/brcampb/projects/manymodels_mlops/oj_sales_data/https%3A/%2Fazureopendatastorage.azurefd.net/ojsales-simulatedcontainer/oj_sales_data/Store1001_tropicana.csv',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/coding-forge-medium/code/Users/brcampb/projects/manymodels_mlops/oj_sales_data/https%3A/%2Fazureopendatastorage.azurefd.net/ojsales-simulatedcontainer/oj_sales_data/Store1002_dominicks.csv',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/coding-forge-medium/code/Users/brcampb/projects/manymodels_mlops/oj_sales_data/https%3A/%2Fazureopendatastorage.azurefd.net/ojsales-simulatedcontainer/oj_sales_data/Store1002_minute.maid.csv',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/coding-forge-medium/code/Users/brcampb/projects/manymodels_mlops/oj_sales_data/https%3A/%2Fazureopendatastorage.azurefd.net/ojsales-simulatedcontainer/oj_sales_data/Store1002_tropicana.csv',
#  '/mnt/batch/tasks/shared/LS_root/mounts/clusters/coding-forge-medium/code/Users/brcampb/projects/manymodels_mlops/oj_sales_data/https%3A/%2Fazureopendatastorage.azurefd.net/ojsales-simulatedcontainer/oj_sales_data/Store1003_dominicks.csv']

# %% [markdown]
# ## 2.0 Split data in two sets
#
# We will now split each dataset in two parts: one will be used for training, and the other will be used for simulating batch forecasting. The training files will contain the data records before '1992-5-28' and the last part of each series will be stored in the inferencing files.
#
# Finally, we will upload both sets of data files to the Workspace's default [Datastore](https://docs.microsoft.compython/api/azureml-core/azureml.core.datastore(class)).

# %%
from scripts.helper import split_data

# Provide name of timestamp column in the data and date from which to split into the inference dataset
timestamp_column = 'WeekStarting'
split_date = '1992-05-28'

# Split each file and store in corresponding directory
train_path, inference_path = split_data(target_path, timestamp_column, split_date)

# %% [markdown]
# ## 3.0 Upload data to Datastore in AML Workspace
#
# In the [setup notebook](00_Setup_AML_Workspace.ipynb) you created a [Workspace](https://docs.microsoft.com/python/api/azureml-core/azureml.core.workspace.workspace). We are going to register the data in that enviroment.

# %%
from azureml.core.workspace import Workspace

ws = Workspace.from_config()

# Take a look at Workspace
ws.get_details()
# Out:
# {'id': '/subscriptions/af3877c2-18a2-4ce2-b67c-a8e21e968128/resourceGroups/coding-forge-rg/providers/Microsoft.MachineLearningServices/workspaces/coding-forge-ml-ws',
#  'name': 'coding-forge-ml-ws',
#  'identity': {'principal_id': '62dda26f-3571-42bf-8c44-ccb3db7f889b',
#   'tenant_id': '72f988bf-86f1-41af-91ab-2d7cd011db47',
#   'type': 'SystemAssigned'},
#  'location': 'eastus',
#  'type': 'Microsoft.MachineLearningServices/workspaces',
#  'tags': {'Created By': 'brandon campbell',
#   'contact': 'brandon.campbell@microsoft.com',
#   'phone': '770.853.0352'},
#  'sku': 'Basic',
#  'workspaceid': 'e057c1f8-0319-435b-92cd-84642f9e37d5',
#  'sdkTelemetryAppInsightsKey': 'f5784ccd-178d-4ecc-9998-b05841b44ae9',
#  'description': '',
#  'friendlyName': 'coding-forge-ml-ws',
#  'creationTime': '2021-09-01T12:30:38.7634249+00:00',
#  'containerRegistry': '/subscriptions/af3877c2-18a2-4ce2-b67c-a8e21e968128/resourcegroups/coding-forge-rg/providers/microsoft.containerregistry/registries/codingforgeacr',
#  'keyVault': '/subscriptions/af3877c2-18a2-4ce2-b67c-a8e21e968128/resourcegroups/coding-forge-rg/providers/microsoft.keyvault/vaults/codingforgekv',
#  'applicationInsights': '/subscriptions/af3877c2-18a2-4ce2-b67c-a8e21e968128/resourcegroups/coding-forge-rg/providers/microsoft.insights/components/codingforgeai',
#  'storageAccount': '/subscriptions/af3877c2-18a2-4ce2-b67c-a8e21e968128/resourcegroups/coding-forge-rg/providers/microsoft.storage/storageaccounts/codingforgesa',
#  'hbiWorkspace': False,
#  'allowPublicAccessWhenBehindVnet': False,
#  'provisioningState': 'Succeeded',
#  'imageBuildCompute': '',
#  'discoveryUrl': 'https://eastus.api.azureml.ms/discovery',
#  'notebookInfo': {'fqdn': 'ml-coding-forge-ml--eastus-e057c1f8-0319-435b-92cd-84642f9e37d5.notebooks.azure.net',
#   'resource_id': '83a76f94073e4e25a7d8cd7ad4e30bc1'}}

# %% [markdown]
# We will upload both sets of data files to your Workspace's default [Datastore](https://docs.microsoft.com/azure/machine-learning/how-to-access-data).
# A Datastore is a place where data can be stored that is then made accessible for training or forecasting. Please refer to [Datastore documentation](https://docs.microsoft.com/python/api/azureml-core/azureml.core.datastore(class)) on how to access data from Datastore.

# %%
# Connect to default datastore
datastore = ws.get_default_datastore()

# Upload train data
ds_train_path = target_path + '_train'
datastore.upload(src_dir=train_path, target_path=ds_train_path, overwrite=True)

# Upload inference data
ds_inference_path = target_path + '_inference'
datastore.upload(src_dir=inference_path, target_path=ds_inference_path, overwrite=True)
# Out:
# Uploading an estimated of 10 files
# Uploading oj_sales_data/upload_train_data/Store1000_dominicks.csv
# Uploaded oj_sales_data/upload_train_data/Store1000_dominicks.csv, 1 files out of an estimated total of 10
# Uploading oj_sales_data/upload_train_data/Store1000_minute.maid.csv
# Uploaded oj_sales_data/upload_train_data/Store1000_minute.maid.csv, 2 files out of an estimated total of 10
# Uploading oj_sales_data/upload_train_data/Store1000_tropicana.csv
# Uploaded oj_sales_data/upload_train_data/Store1000_tropicana.csv, 3 files out of an estimated total of 10
# Uploading oj_sales_data/upload_train_data/Store1001_dominicks.csv
# Uploaded oj_sales_data/upload_train_data/Store1001_dominicks.csv, 4 files out of an estimated total of 10
# Uploading oj_sales_data/upload_train_data/Store1001_minute.maid.csv
# Uploaded oj_sales_data/upload_train_data/Store1001_minute.maid.csv, 5 files out of an estimated total of 10
# Uploading oj_sales_data/upload_train_data/Store1001_tropicana.csv
# Uploaded oj_sales_data/upload_train_data/Store1001_tropicana.csv, 6 files out of an estimated total of 10
# Uploading oj_sales_data/upload_train_data/Store1002_dominicks.csv
# Uploaded oj_sales_data/upload_train_data/Store1002_dominicks.csv, 7 files out of an estimated total of 10
# Uploading oj_sales_data/upload_train_data/Store1002_minute.maid.csv
# Uploaded oj_sales_data/upload_train_data/Store1002_minute.maid.csv, 8 files out of an estimated total of 10
# Uploading oj_sales_data/upload_train_data/Store1002_tropicana.csv
# Uploaded oj_sales_data/upload_train_data/Store1002_tropicana.csv, 9 files out of an estimated total of 10
# Uploading oj_sales_data/upload_train_data/Store1003_dominicks.csv
# Uploaded oj_sales_data/upload_train_data/Store1003_dominicks.csv, 10 files out of an estimated total of 10
# Uploaded 10 files
# Uploading an estimated of 10 files
# Uploading oj_sales_data/upload_inference_data/Store1000_dominicks.csv
# Uploaded oj_sales_data/upload_inference_data/Store1000_dominicks.csv, 1 files out of an estimated total of 10
# Uploading oj_sales_data/upload_inference_data/Store1000_minute.maid.csv
# Uploaded oj_sales_data/upload_inference_data/Store1000_minute.maid.csv, 2 files out of an estimated total of 10
# Uploading oj_sales_data/upload_inference_data/Store1000_tropicana.csv
# Uploaded oj_sales_data/upload_inference_data/Store1000_tropicana.csv, 3 files out of an estimated total of 10
# Uploading oj_sales_data/upload_inference_data/Store1001_dominicks.csv
# Uploaded oj_sales_data/upload_inference_data/Store1001_dominicks.csv, 4 files out of an estimated total of 10
# Uploading oj_sales_data/upload_inference_data/Store1001_minute.maid.csv
# Uploaded oj_sales_data/upload_inference_data/Store1001_minute.maid.csv, 5 files out of an estimated total of 10
# Uploading oj_sales_data/upload_inference_data/Store1001_tropicana.csv
# Uploaded oj_sales_data/upload_inference_data/Store1001_tropicana.csv, 6 files out of an estimated total of 10
# Uploading oj_sales_data/upload_inference_data/Store1002_dominicks.csv
# Uploaded oj_sales_data/upload_inference_data/Store1002_dominicks.csv, 7 files out of an estimated total of 10
# Uploading oj_sales_data/upload_inference_data/Store1002_minute.maid.csv
# Uploaded oj_sales_data/upload_inference_data/Store1002_minute.maid.csv, 8 files out of an estimated total of 10
# Uploading oj_sales_data/upload_inference_data/Store1002_tropicana.csv
# Uploaded oj_sales_data/upload_inference_data/Store1002_tropicana.csv, 9 files out of an estimated total of 10
# Uploading oj_sales_data/upload_inference_data/Store1003_dominicks.csv
# Uploaded oj_sales_data/upload_inference_data/Store1003_dominicks.csv, 10 files out of an estimated total of 10
# Uploaded 10 files
# $AZUREML_DATAREFERENCE_1cc17acca9524a7e9cb1855ac0339c92

# %% [markdown]
# ### *[Optional]* If data is already in Azure: create Datastore from it
#
# If your data is already in Azure you don't need to upload it from your local machine to the default datastore. Instead, you can create a new Datastore that references that set of data.
# The following is an example of how to set up a Datastore from a container in Blob storage where the sample data is located.
#
# In this case, the orange juice data is available in a public blob container, defined by the information below. In your case, you'll need to specify the account credentials as well. For more information check [the documentation](https://docs.microsoft.com/python/api/azureml-core/azureml.core.datastore.datastore#register-azure-blob-container-workspace--datastore-name--container-name--account-name--sas-token-none--account-key-none--protocol-none--endpoint-none--overwrite-false--create-if-not-exists-false--skip-validation-false--blob-cache-timeout-none--grant-workspace-access-false--subscription-id-none--resource-group-none-).

# %%
blob_datastore_name = "automl_many_models"
container_name = "automl-sample-notebook-data"
account_name = "automlsamplenotebookdata"

# %%
from azureml.core import Datastore

datastore = Datastore.register_azure_blob_container(
    workspace=ws, 
    datastore_name=blob_datastore_name, 
    container_name=container_name,
    account_name=account_name,
    create_if_not_exists=True
)

if 0 < dataset_maxfiles < 11973:
    ds_train_path = 'oj_data_small/'
    ds_inference_path = 'oj_inference_small/'
else:
    ds_train_path = 'oj_data/'
    ds_inference_path = 'oj_inference/'

# %% [markdown]
# ## 4.0 Register dataset in AML Workspace
#
# The last step is creating and registering [datasets](https://docs.microsoft.com/azure/machine-learning/concept-data#datasets) in Azure Machine Learning for the train and inference sets.
#
# Using a [FileDataset](https://docs.microsoft.com/python/api/azureml-core/azureml.data.file_dataset.filedataset) is currently the best way to take advantage of the many models pattern, so we create FileDatasets in the next cell. We then [register](https://docs.microsoft.com/azure/machine-learning/how-to-create-register-datasets#register-datasets) the FileDatasets in your Workspace; this associates the train/inference sets with simple names that can be easily referred to later on when we train models and produce forecasts.

# %%
from azureml.core.dataset import Dataset

# Create file datasets
ds_train = Dataset.File.from_files(path=datastore.path(ds_train_path), validate=False)
ds_inference = Dataset.File.from_files(path=datastore.path(ds_inference_path), validate=False)

# Register the file datasets
dataset_name = 'oj_data_small' if 0 < dataset_maxfiles < 11973 else 'oj_data'
train_dataset_name = dataset_name + '_train'
inference_dataset_name = dataset_name + '_inference'
ds_train.register(ws, train_dataset_name, create_new_version=True)
ds_inference.register(ws, inference_dataset_name, create_new_version=True)
# Out:
# {
#   "source": [
#     "('automl_many_models', 'oj_inference_small/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "59f4fec2-cee8-4e64-99dd-b686ad96c58e",
#     "name": "oj_data_small_inference",
#     "version": 1,
#     "workspace": "Workspace.create(name='coding-forge-ml-ws', subscription_id='af3877c2-18a2-4ce2-b67c-a8e21e968128', resource_group='coding-forge-rg')"
#   }
# }

# %% [markdown]
# ## 5.0 *[Optional]* Interact with the registered dataset
#
# After registering the data, it can be easily called using the command below. This is how the datasets will be accessed in future notebooks.

# %%
oj_ds = Dataset.get_by_name(ws, name=train_dataset_name)
oj_ds
# Out:
# {
#   "source": [
#     "('automl_many_models', 'oj_data_small/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "f31d6346-74e4-4a52-afd0-f7ec048ff351",
#     "name": "oj_data_small_train",
#     "version": 1,
#     "workspace": "Workspace.create(name='coding-forge-ml-ws', subscription_id='af3877c2-18a2-4ce2-b67c-a8e21e968128', resource_group='coding-forge-rg')"
#   }
# }

# %% [markdown]
# It is also possible to download the data from the registered dataset:

# %%
download_paths = oj_ds.download()
download_paths
# Out:
# ['/tmp/tmpbxm0yeo6/Store1000_dominicks.csv',
#  '/tmp/tmpbxm0yeo6/Store1000_minute.maid.csv',
#  '/tmp/tmpbxm0yeo6/Store1000_tropicana.csv',
#  '/tmp/tmpbxm0yeo6/Store1001_dominicks.csv',
#  '/tmp/tmpbxm0yeo6/Store1001_minute.maid.csv',
#  '/tmp/tmpbxm0yeo6/Store1001_tropicana.csv',
#  '/tmp/tmpbxm0yeo6/Store1002_dominicks.csv',
#  '/tmp/tmpbxm0yeo6/Store1002_minute.maid.csv',
#  '/tmp/tmpbxm0yeo6/Store1002_tropicana.csv',
#  '/tmp/tmpbxm0yeo6/Store1003_dominicks.csv']

# %% [markdown]
# Let's load one of the data files to see the format:

# %%
import pandas as pd

sample_data = pd.read_csv(download_paths[0])
sample_data.head(10)
# Out:
#   WeekStarting  Store      Brand  Quantity  Advert  Price   Revenue
# 0   1990-06-14   1000  dominicks     12003       1   2.59  31087.77
# 1   1990-06-21   1000  dominicks     10239       1   2.39  24471.21
# 2   1990-06-28   1000  dominicks     17917       1   2.48  44434.16
# 3   1990-07-05   1000  dominicks     14218       1   2.33  33127.94
# 4   1990-07-12   1000  dominicks     15925       1   2.01  32009.25
# 5   1990-07-19   1000  dominicks     17850       1   2.17  38734.50
# 6   1990-07-26   1000  dominicks     10576       1   1.97  20834.72
# 7   1990-08-02   1000  dominicks      9912       1   2.26  22401.12
# 8   1990-08-09   1000  dominicks      9571       1   2.11  20194.81
# 9   1990-08-16   1000  dominicks     15748       1   2.42  38110.16

# %% [markdown]
# ## Next Steps
#
# Now that you have created your datasets, you are ready to move to one of the training notebooks to train and score the models:
#
# - Automated ML: please open [02_AutoML_Training_Pipeline.ipynb](Automated_ML/02_AutoML_Training_Pipeline/02_AutoML_Training_Pipeline.ipynb).
# - Custom Script: please open [02_CustomScript_Training_Pipeline.ipynb](Custom_Script/02_CustomScript_Training_Pipeline.ipynb).
